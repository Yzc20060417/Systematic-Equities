# %% [markdown]
# # Exploratory Data Analysis (EDA) Lab

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import re
import json

# %%
import analytics
import operators_library

# %% [markdown]
# # Project1: Factor Regime-Driven

# %% [markdown]
# # Project2: Liquidity vs. Volaitility
